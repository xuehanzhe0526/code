# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pandas import Series, DataFrame

# %%
ls
# Out:
# 10_12数据分析_理解数据.pdf  npm-debug.log  理解样本数据.ipynb
# douban.dat                  tips.csv       数据挖掘-数据预处理.ipynb

# %%
tips=pd.read_csv('tips.csv')

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
tips[['sex','smoker','day','time']].describe()
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# ### DataFrame 索引总结

# %%
tips['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
# 5        Male
# 6        Male
# 7        Male
# 8        Male
# 9        Male
# 10       Male
# 11     Female
# 12       Male
# 13       Male
# 14     Female
# 15       Male
# 16     Female
# 17       Male
# 18     Female
# 19       Male
# 20       Male
# 21     Female
# 22     Female
# 23       Male
# 24       Male
# 25       Male
# 26       Male
# 27       Male
# 28       Male
# 29     Female
#         ...
# 214    Female
# 215    Female
# 216      Male
# 217      Male
# 218      Male
# 219    Female
# 220      Male
# 221    Female
# 222      Male
# 223    Female
# 224      Male
# 225    Female
# 226    Female
# 227      Male
# 228      Male
# 229    Female
# 230      Male
# 231      Male
# 232      Male
# 233      Male
# 234      Male
# 235      Male
# 236      Male
# 237      Male
# 238    Female
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# ...

# %%
tips.iat[0,2]
# Out:
# 'Female'

# %%
tips.loc[:,['sex','size']]
# Out:
#         sex  size
# 0    Female     2
# 1      Male     3
# 2      Male     3
# 3      Male     2
# 4    Female     4
# 5      Male     4
# 6      Male     2
# 7      Male     4
# 8      Male     2
# 9      Male     2
# 10     Male     2
# 11   Female     4
# 12     Male     2
# 13     Male     4
# 14   Female     2
# 15     Male     2
# 16   Female     3
# 17     Male     3
# 18   Female     3
# 19     Male     3
# 20     Male     2
# 21   Female     2
# 22   Female     2
# 23     Male     4
# 24     Male     2
# 25     Male     4
# 26     Male     2
# 27     Male     2
# 28     Male     2
# 29   Female     2
# ..      ...   ...
# 214  Female     3
# 215  Female     2
# 216    Male     5
# 217    Male     2
# 218    Male     2
# 219  Female     4
# 220    Male     2
# 221  Female     2
# 222    Male     1
# 223  Female     3
# 224    Male     2
# 225  Female     2
# 226  Female     2
# 227    Male     4
# 228    Male     2
# 229  Female     2
# 230    Male     4
# 231    Male     3
# ...

# %%
tips.iloc[0,2]
# Out:
# 'Female'

# %%
tips.iloc[0:4,2:4]
# Out:
#       sex smoker
# 0  Female     No
# 1    Male     No
# 2    Male     No
# 3    Male     No

# %% [markdown]
# ### DataFrame的合并

# %%
tips1=tips[:100]

# %%
tips2=tips[100:]

# %%
tip12=pd.concat([tips1,tips2])#按行

# %% [markdown]
# 按列合并

# %%
left = pd.DataFrame({'key': ['foo', 'foo1'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo1'], 'rval': [4, 5]})

# %%
left
# Out:
#     key  lval
# 0   foo     1
# 1  foo1     2

# %%
right
# Out:
#     key  rval
# 0   foo     4
# 1  foo1     5

# %%
pd.merge(left, right, on='key')
# Out:
#     key  lval  rval
# 0   foo     1     4
# 1  foo1     2     5

# %%
s1=tips.iloc[4] ##Appende

# %%
s1
# Out:
# total_bill     24.59
# tip             3.61
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 4, dtype: object

# %%
tips.append(s1)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.append(s1,ignore_index=True) #序列号继续
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# sort 和 groupby

# %%
tips.sort('tip')
# Out:
# /home/xuehaozhe/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 215       12.90   1.10  Female    Yes   Sat  Dinner     2
# 237       32.83   1.17    Male    Yes   Sat  Dinner     2
# 235       10.07   1.25    Male     No   Sat  Dinner     2
# 75        10.51   1.25    Male     No   Sat  Dinner     2
# 135        8.51   1.25  Female     No  Thur   Lunch     2
# 43         9.68   1.32    Male     No   Sun  Dinner     2
# 146       18.64   1.36  Female     No  Thur   Lunch     3
# ...

# %%
tips.sort(['tip','total_bill'])
# Out:
# /home/xuehaozhe/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 215       12.90   1.10  Female    Yes   Sat  Dinner     2
# 237       32.83   1.17    Male    Yes   Sat  Dinner     2
# 135        8.51   1.25  Female     No  Thur   Lunch     2
# 235       10.07   1.25    Male     No   Sat  Dinner     2
# 75        10.51   1.25    Male     No   Sat  Dinner     2
# 43         9.68   1.32    Male     No   Sun  Dinner     2
# 146       18.64   1.36  Female     No  Thur   Lunch     3
# ...

# %%
tips.sort(['sex','tip'],ascending=[True,False])#降序
# Out:
# /home/xuehaozhe/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#      total_bill   tip     sex smoker   day    time  size
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 191       19.81  4.19  Female    Yes  Thur   Lunch     2
# ...

# %% [markdown]
# #### groupby 分组

# %%
tips.groupby('sex').sum()
# Out:
#         total_bill     tip  size
# sex
# Female     1570.95  246.51   214
# Male       3256.82  485.07   413

# %%
tips.groupby(['sex','size']).sum()
# Out:
#              total_bill     tip
# sex    size
# Female 1          20.39    3.83
#        2         889.69  146.65
#        3         301.66   45.50
#        4         272.51   36.19
#        5          29.85    5.14
#        6          56.85    9.20
# Male   1           8.58    1.92
#        2        1676.20  256.19
#        3         582.89   83.44
#        4         786.19  116.82
#        5         120.49   15.00
#        6          82.47   11.70

# %% [markdown]
# ### apply

# %%
tips[['total_bill','tip','size']].apply(lambda x: x.max()-x.min())
# Out:
# total_bill    47.74
# tip            9.00
# size           5.00
# dtype: float64

# %% [markdown]
# ### Categorical Data 类别型数据
#
# – 有限的取值:如性别,星座,年级
#
# – 加减乘除没有意义
#
# – 分为有序的和无序的
#
# • 有序的如,改进程度;
#
# • 无序的如,性别;

# %%
s = pd.Series(["a","b","c","a"], dtype="category")

# %%
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# dtype: category
# Categories (3, object): [a, b, c]

# %%
s = pd.Series(["a","b","c","a"])
s_cat = s.astype("category", categories=["b","c","d"],ordered=False)

# %%
s_cat
# Out:
# 0    NaN
# 1      b
# 2      c
# 3    NaN
# dtype: category
# Categories (3, object): [b, c, d]

# %%
s_cat = s.astype("category", categories=["b","c","d"],ordered=True)

# %%
s_cat
# Out:
# 0    NaN
# 1      b
# 2      c
# 3    NaN
# dtype: category
# Categories (3, object): [b < c < d]

# %%
tips['sex']=tips['sex'].astype('category')

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker          object
# day             object
# time            object
# size             int64
# dtype: object

# %%
tips['sex'].describe()
# Out:
# count      244
# unique       2
# top       Male
# freq       157
# Name: sex, dtype: object

# %%
tips['sex'].cat.ordered ##是否有序
# Out:
# False

# %%
tips['sex']=tips['sex'].cat.set_categories(['Male','Female'],ordered=True)

# %%
tips['sex'].cat.ordered ##是否有序
# Out:
# True

# %% [markdown]
# ### Scipy

# %%
from scipy import stats

# %%
tips['tips_pct']=tips['tip']/tips['total_bill']

# %%
# %matplotlib inline
tips['tip'].hist(bins=50)

# %%
tips['tips_pct'].hist(bins=50)

# %% [markdown]
# ### 用数字特征检验
#
# 看分布的数字特征是否不理论的数字特征一致?

# %%
np.random.seed(28)#种子
x = stats.t.rvs(10, size=1000)

# %%
#计算其数字特征
print x.max(), x.min(),x.mean(),x.var()
# Out:
# 4.69954830162 -4.19862883779 -0.0181924949797 1.27567812869

# %%
n, (smin, smax), sm, sv, ss, sk = stats.describe(x)
print n, (smin, smax), sm, sv, ss, sk
# Out:
# 1000 (-4.1986288377860115, 4.6995483016155886) -0.0181924949797 1.27695508378 0.12936915509 1.06282830398

# %%
# 计算理论数字特征
m, v, s, k = stats.t.stats(10, moments='mvsk') #距
print m,v,s,k
# Out:
# 0.0 1.25 0.0 1.0

# %% [markdown]
# ### 更严格的检验
#
# m, v, s, k = stats.t.stats(10, moments='mvsk') #距

# %%
stats.ttest_1samp(x, m)
# Out:
# Ttest_1sampResult(statistic=-0.50910158954887641, pvalue=0.61079344177204575)

# %%
print 't-statistic = %6.3f pvalue = %6.4f' %stats.ttest_1samp(x, m)
# Out:
# t-statistic = -0.509 pvalue = 0.6108

# %% [markdown]
# ### K-S test

# %%
stats.kstest(x, 't', (10,))
# Out:
# KstestResult(statistic=0.021462484753307809, pvalue=0.7463327701571878)

# %%
print 'KS-statistic D = %6.3f pvalue = %6.4f' % stats.kstest(x,'t', (10,))
# Out:
# KS-statistic D =  0.021 pvalue = 0.7463

# %%
#是否符合正态分布?
stats.kstest(x, 'norm', (x.mean(),x.std()))
# Out:
# KstestResult(statistic=0.028996191653634873, pvalue=0.36506309045788576)

# %% [markdown]
# ### 卡方检验

# %%
quantiles = [0.0, 0.01, 0.05, 0.1, 1-0.10, 1-0.05, 1-0.01, 1.0]

# %%
crit = stats.t.ppf(quantiles, 10)

# %%
crit
# Out:
# array([       -inf, -2.76376946, -1.81246112, -1.37218364,  1.37218364,
#         1.81246112,  2.76376946,         inf])

# %%
n_sample = x.size

# %%
x.size
# Out:
# 1000

# %%
np.histogram(x, bins=crit)
# Out:
# (array([  8,  50,  51, 791,  49,  42,   9]),
#  array([       -inf, -2.76376946, -1.81246112, -1.37218364,  1.37218364,
#          1.81246112,  2.76376946,         inf]))

# %%
freqcount = np.histogram(x, bins=crit)[0]

# %%
freqcount
# Out:
# array([  8,  50,  51, 791,  49,  42,   9])

# %%
plt.hist(x,bins=crit)
# Out:
# (array([   8.,   50.,   51.,  791.,   49.,   42.,    9.]),
#  array([       -inf, -2.76376946, -1.81246112, -1.37218364,  1.37218364,
#          1.81246112,  2.76376946,         inf]),
#  <a list of 7 Patch objects>)

# %%
plt.hist(x,bins=50)
# Out:
# (array([  2.,   2.,   0.,   0.,   0.,   1.,   0.,   3.,   1.,   4.,   7.,
#          12.,  17.,  15.,  28.,  18.,  34.,  39.,  39.,  56.,  63.,  52.,
#          81.,  65.,  57.,  65.,  73.,  50.,  47.,  34.,  25.,  28.,  22.,
#          10.,  11.,  14.,   7.,   5.,   3.,   1.,   0.,   1.,   1.,   2.,
#           0.,   1.,   2.,   0.,   1.,   1.]),
#  array([-4.19862884, -4.02066529, -3.84270175, -3.66473821, -3.48677467,
#         -3.30881112, -3.13084758, -2.95288404, -2.7749205 , -2.59695695,
#         -2.41899341, -2.24102987, -2.06306632, -1.88510278, -1.70713924,
#         -1.5291757 , -1.35121215, -1.17324861, -0.99528507, -0.81732152,
#         -0.63935798, -0.46139444, -0.2834309 , -0.10546735,  0.07249619,
#          0.25045973,  0.42842327,  0.60638682,  0.78435036,  0.9623139 ,
#          1.14027745,  1.31824099,  1.49620453,  1.67416807,  1.85213162,
#          2.03009516,  2.2080587 ,  2.38602225,  2.56398579,  2.74194933,
# ...

# %%
tprob = np.diff(quantiles) #差分

# %%
tprob
# Out:
# array([ 0.01,  0.04,  0.05,  0.8 ,  0.05,  0.04,  0.01])

# %%
freqcount
# Out:
# array([  8,  50,  51, 791,  49,  42,   9])

# %%
tprob*1000
# Out:
# array([  10.,   40.,   50.,  800.,   50.,   40.,   10.])

# %%
nprob = np.diff(stats.norm.cdf(crit))
tch, tpval = stats.chisquare(freqcount, tprob*n_sample)

# %%
print tch,tpval
# Out:
# 3.24125 0.778014950976

# %%
npval = stats.chisquare(freqcount, nprob*n_sample)

# %%
print nch,npval
# Out:
# 37.3738214874 Power_divergenceResult(statistic=37.373821487421949, pvalue=1.4887508781592335e-06)

# %%
1000*nprob
# Out:
# array([   2.85689468,   32.10059323,   50.04565043,  829.99372331,
#          50.04565043,   32.10059323,    2.85689468])

# %%
freqcount
# Out:
# array([  8,  50,  51, 791,  49,  42,   9])

# %% [markdown]
# ### 正态分布检验

# %%
x
# Out:
# array([  3.27605881e-01,   1.56758992e+00,   3.74602273e-01,
#         -2.06542614e-01,   5.41958224e-01,   1.35023791e+00,
#         -7.16874666e-01,   5.69488078e-01,  -1.19232971e-01,
#          4.95237835e-01,  -7.73701291e-01,  -1.07995740e+00,
#         -7.15478782e-01,   7.97833258e-01,  -1.33051595e+00,
#          1.32120117e+00,   3.87232554e-01,   1.21358547e+00,
#         -5.05065403e-02,   9.95364393e-02,   1.47132345e+00,
#         -2.01319943e+00,   7.70974959e-01,   1.26295653e+00,
#          6.17431070e-01,  -2.64826711e-01,  -1.72911870e+00,
#         -3.47015888e-01,   2.24103311e+00,  -5.39979146e-01,
#          7.98150202e-01,  -5.02596707e-01,  -6.89732038e-01,
#         -2.18695586e+00,   7.80259319e-01,  -8.23896404e-01,
#          8.85209194e-02,   6.71346979e-01,   6.79694788e-01,
#         -1.43050534e+00,  -1.45272294e+00,  -5.98409707e-01,
#          3.97531396e-01,  -5.63677465e-01,   2.94313482e-01,
# ...

# %%
stats.normaltest(x)
# Out:
# NormaltestResult(statistic=25.641309809968341, pvalue=2.7043339505576926e-06)

# %%
stats.normaltest(tips['tip'])
# Out:
# NormaltestResult(statistic=79.37862574074785, pvalue=5.7962943229071017e-18)

# %%
tips['tip_pct']=tips['tip']/tips['total_bill']

# %%
tips['tip_pct']
# Out:
# 0      0.059447
# 1      0.160542
# 2      0.166587
# 3      0.139780
# 4      0.146808
# 5      0.186240
# 6      0.228050
# 7      0.116071
# 8      0.130319
# 9      0.218539
# 10     0.166504
# 11     0.141804
# 12     0.101816
# 13     0.162778
# 14     0.203641
# 15     0.181650
# 16     0.161665
# 17     0.227747
# 18     0.206246
# 19     0.162228
# 20     0.227679
# 21     0.135535
# 22     0.141408
# 23     0.192288
# 24     0.160444
# 25     0.131387
# 26     0.149589
# 27     0.157604
# 28     0.198157
# 29     0.152672
#          ...
# 214    0.230742
# 215    0.085271
# 216    0.106572
# 217    0.129422
# 218    0.186047
# 219    0.102522
# 220    0.180921
# 221    0.259314
# 222    0.223776
# 223    0.187735
# 224    0.117735
# 225    0.153657
# 226    0.198216
# 227    0.146699
# 228    0.204819
# 229    0.130199
# 230    0.083299
# 231    0.191205
# 232    0.291990
# 233    0.136490
# 234    0.193175
# 235    0.124131
# 236    0.079365
# 237    0.035638
# ...

# %%
tips.tip_pct.hist()

# %%
tips.tip_pct.hist(bins=50)

# %%
stats.normaltest(tips['tip_pct'])
# Out:
# NormaltestResult(statistic=220.88797288158281, pvalue=1.0833932598440914e-48)

# %%
## 假设：异常点引起的?

# %%
tips[tips['tip_pct']>0.4]
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_pct   tip_pct
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  0.710345  0.710345
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  0.416667  0.416667

# %%
tips1=tips.drop([172,178])

# %%
stats.normaltest(tips1['tip_pct'])
# Out:
# NormaltestResult(statistic=4.684342675054582, pvalue=0.096118705328701121)

# %%
tips1['tip_pct'].hist(bins=50)

# %%
tips[tips['tip_pct']>0.3]
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_pct   tip_pct
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1  0.325733  0.325733
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  0.710345  0.710345
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  0.416667  0.416667

# %%
tips1=tips.drop([67,172,178]) ##三个异常点

# %%
tips1['tip_pct'].hist(bins=50)

# %%
stats.normaltest(tips1['tip_pct'])
# Out:
# NormaltestResult(statistic=0.77248697213228978, pvalue=0.67960503117776228)

# %% [markdown]
# ### 比较两个样本

# %%
#比较两组均值
rvs1 = stats.norm.rvs(loc=5, scale=10, size=500)
rvs2 = stats.norm.rvs(loc=5, scale=10, size=500)
stats.ttest_ind(rvs1, rvs2)
# Out:
# Ttest_indResult(statistic=1.4314775592474362, pvalue=0.15260646806037226)

# %%
rvs3 = stats.norm.rvs(loc=8, scale=10, size=500)

# %%
stats.ttest_ind(rvs1, rvs3)
# Out:
# Ttest_indResult(statistic=-3.5010307252353994, pvalue=0.00048396381749773836)

# %%
#Kolmogorov-Smirnov 双样本检测 ks_2samp
stats.ks_2samp(rvs1, rvs2)
# Out:
# Ks_2sampResult(statistic=0.084000000000000019, pvalue=0.055478621048521547)

# %%
stats.ks_2samp(rvs1, rvs3)
# Out:
# Ks_2sampResult(statistic=0.10599999999999998, pvalue=0.0066347509626213941)
